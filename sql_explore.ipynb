# %%
# This will download the necessary add-ons so that we can run sql code

# !pip install ipython-sql
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: ipython-sql in c:\users\jnuso\appdata\roaming\python\python314\site-packages (0.5.0)
# Requirement already satisfied: prettytable in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython-sql) (3.17.0)
# Requirement already satisfied: ipython in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython-sql) (9.12.0)
# Requirement already satisfied: sqlalchemy>=2.0 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython-sql) (2.0.49)
# Requirement already satisfied: sqlparse in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: greenlet>=1 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from sqlalchemy>=2.0->ipython-sql) (3.4.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython->ipython-sql) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from jedi>=0.18.2->ipython->ipython-sql) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\jnuso\appdata\roaming\python\python314\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: C:\Python314\python.exe -m pip install --upgrade pip

# %%
# %pip install ipython-sql sqlalchemy
# %load_ext sql
# Out:
# Collecting ipython-sql
#   Using cached ipython_sql-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting sqlalchemy
#   Downloading sqlalchemy-2.0.49-cp313-cp313-win_amd64.whl.metadata (9.8 kB)
# Collecting prettytable (from ipython-sql)
#   Using cached prettytable-3.17.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: ipython in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from ipython-sql) (9.9.0)
# Collecting sqlparse (from ipython-sql)
#   Using cached sqlparse-0.5.5-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: six in c:\Users\Jnuso\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipython-sql) (1.17.0)
# Collecting ipython-genutils (from ipython-sql)
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl.metadata (755 bytes)
# Collecting greenlet>=1 (from sqlalchemy)
#   Downloading greenlet-3.4.0-cp313-cp313-win_amd64.whl.metadata (3.8 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\Users\Jnuso\AppData\Local\Programs\Python\Python313\Lib\site-packages (from sqlalchemy) (4.15.0)
# Requirement already satisfied: colorama>=0.4.4 in c:\Users\Jnuso\AppData\Local\Programs\Python\Python313\Lib\site-packages (from ipython->ipython-sql) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from ipython->ipython-sql) (5.14.3)
# Requirement already satisfied: wcwidth in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipython-sql) (0.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from jedi>=0.18.1->ipython->ipython-sql) (0.8.5)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\Jnuso\AppData\Roaming\Python\Python313\site-packages (from stack_data>=0.6.0->ipython->ipython-sql) (0.2.3)
# Using cached ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# Downloading sqlalchemy-2.0.49-cp313-cp313-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ------------------- -------------------- 1.0/2.1 MB 7.2 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.2 MB/s  0:00:00
# Downloading greenlet-3.4.0-cp313-cp313-win_amd64.whl (238 kB)
# Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Using cached prettytable-3.17.0-py3-none-any.whl (34 kB)
# Using cached sqlparse-0.5.5-py3-none-any.whl (46 kB)
# Installing collected packages: ipython-genutils, sqlparse, prettytable, greenlet, sqlalchemy, ipython-sql
#
#    ---------------------------------------- 0/6 [ipython-genutils]
#    ------ --------------------------------- 1/6 [sqlparse]
#    ------ --------------------------------- 1/6 [sqlparse]
#    ------ --------------------------------- 1/6 [sqlparse]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------- ------------------- 3/6 [greenlet]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    -------------------------- ------------- 4/6 [sqlalchemy]
#    --------------------------------- ------ 5/6 [ipython-sql]
#    ---------------------------------------- 6/6 [ipython-sql]
#
# Successfully installed greenlet-3.4.0 ipython-genutils-0.2.0 ipython-sql-0.5.0 prettytable-3.17.0 sqlalchemy-2.0.49 sqlparse-0.5.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# %config SqlMagic.style = '_DEPRECATED_DEFAULT'

# %%
# This will depend on the location where example.db is saved

# %sql sqlite:///example.db

# %%
# Test to see if it works 

# %sql select * from customers
# Out:
#  * sqlite:///example.db
# (sqlite3.OperationalError) no such table: customers
# [SQL: select * from customers]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql select LastName from customers where CustomerID=2
# Out:
#  * sqlite:///example.db
# (sqlite3.OperationalError) no such table: customers
# [SQL: select LastName from customers where CustomerID=2]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql pragma table_info(customers)
# Out:
#  * sqlite:///example.db
# Done.
# []

# %%
# %sql pragma table_list
# Out:
#  * sqlite:///example.db
# Done.
# [('main', 'sqlite_schema', 'table', 5, 0, 0),
#  ('temp', 'sqlite_temp_schema', 'table', 5, 0, 0)]

# %%
# %sql select lastname from customers;
# Out:
#  * sqlite:///example.db
# (sqlite3.OperationalError) no such table: customers
# [SQL: select lastname from customers;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %%
# %sql select * from customers limit 3;
# Out:
#  * sqlite:///example.db
# (sqlite3.OperationalError) no such table: customers
# [SQL: select * from customers limit 3;]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)

# %% [markdown]
# ### Exercise 1:
# Retrieve a list of customers’ first name, last name, city, and country, and sort them by last name. The column names should be “First,” “Last,” “City,” and “Country,” in that order.

# %%
# %sql select firstname as "first", lastname as "last" from customers order by first, last desc;

# %%
# %sql select * from tracks;

# %%
# %sql select * from invoices;

# %%
# %sql select customerid, total from invoices where customerid=2;

# %%
# %sql select CustomerID, Total*1.09 as "InflatedPrice", CustomerID + Total as "UselessNumber" FROM invoices;

# %%
# %sql select customerid, count(customerID) as Transactions from invoices group by customerid;

# %%
# %sql select customerid, sum(Total) as GrandTotal from invoices group by customerid;

# %% [markdown]
# ### Exercise 2:
# Retrieve a list of the maximum invoice amount (from the total column) by country. Make sure the list is sorted by country name.

# %%
# %sql select * from albums;

# %%
# %sql select * from artists;

# %% [markdown]
# ### Exercise 3:
# How do left and right join produce different results?

# %%
# %sql SELECT ALB.Title as "Album", ART.Name as "Artist" FROM albums as ALB RIGHT JOIN artists as ART on ALB.ArtistID = ART.ArtistID;

# %%
# %sql create table alb_art_left as SELECT ALB.Title as "Album", ART.Name as "Artist" FROM albums as ALB left JOIN artists as ART on ALB.ArtistID = ART.ArtistID;

# %%
# %sql select count(*) from alb_art_left

# %%
# %sql create table alb_art_right as SELECT ALB.Title as "Album", ART.Name as "Artist" FROM albums as ALB right JOIN artists as ART on ALB.ArtistID = ART.ArtistID;

# %%
# %sql select count(*) from alb_art_right

# %%
# %sql select * from tracks order by bytes desc limit 5;

# %%
# %sql select * from employees;

# %%
# %sql select * from playlists;

# %% [markdown]
# ### More exercises

# %% [markdown]
# Retrieve the 5 largest songs (using bytes) from the tracks table.

# %% [markdown]
# Use a series of joins to list the corresponding genre for each artist in the database.

# %% [markdown]
# Use a self join on the employees table to match each employee’s last name to their manager’s last name.

# %% [markdown]
# Calculate the total number of minutes of music on each playlist.
